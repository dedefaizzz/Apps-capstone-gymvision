# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/GitHub/
# Out:
# /content/drive/MyDrive/GitHub

# %%
# !git init capstone
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/GitHub/capstone/.git/

# %%
# %cd capstone
# Out:
# /content/drive/MyDrive/GitHub/capstone

# %%
# %ls -a
# Out:
# .git/

# %%
# !git status
# Out:
# On branch master
#
# No commits yet
#
# nothing to commit (create/copy files and use "git add" to track)

# %%
# !git remote add -m https://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@github.com/TegarNH/Capstone-Project-C22-PS135.git
# Out:
# usage: git remote add [<options>] <name> <url>
#
#     -f, --fetch           fetch the remote branches
#     --tags                import all tags and associated objects when fetching
#                           or do not fetch any tag at all (--no-tags)
#     -t, --track <branch>  branch(es) to track
#     -m, --master <branch>
#                           master branch
#     --mirror[=<push|fetch>]
#                           set up remote as a mirror to push to or fetch from

# %%
# !git pull https://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@github.com/TegarNH/Capstone-Project-C22-PS135.git main
# Out:
# remote: Enumerating objects: 1411, done.
# remote: Counting objects: 100% (1004/1004), done.
# remote: Compressing objects: 100% (886/886), done.
# remote: Total 1411 (delta 107), reused 926 (delta 84), pack-reused 407
# Receiving objects: 100% (1411/1411), 35.21 MiB | 13.46 MiB/s, done.
# Resolving deltas: 100% (222/222), done.
# From https://github.com/TegarNH/Capstone-Project-C22-PS135
#  * branch            main       -> FETCH_HEAD
# Checking out files: 100% (1798/1798), done.

# %%
# !git add .

# %%
# !git status
# Out:
# On branch master
# Changes to be committed:
#   (use "git reset HEAD <file>..." to unstage)
#
# 	new file:   ML/Model/skin-disease-model-72.h5

# %%
# !git commit -m "tambah model skin-disease"
# Out:
# [master 610ef8a] tambah model skin-disease
#  1 file changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 ML/Model/skin-disease-model-72.h5

# %%
# !git config --global user.email "melika.candra@gmail.com"
# !git config --global user.name "Ni Luh Melika Candra Widyani Mas"

# %%
# !git push https://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@github.com/TegarNH/Capstone-Project-C22-PS135.git master
# Out:
# Counting objects: 12, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (11/11), done.
# error: RPC failed; curl 55 Failed sending data to the peer
# fatal: The remote end hung up unexpectedly
# Writing objects: 100% (12/12), 603.40 MiB | 11.90 MiB/s, done.
# Total 12 (delta 2), reused 0 (delta 0)
# fatal: The remote end hung up unexpectedly
# Everything up-to-date

# %%
# !git config --global
# Out:
# usage: git config [<options>]
#
# Config file location
#     --global              use global config file
#     --system              use system config file
#     --local               use repository config file
#     -f, --file <file>     use given config file
#     --blob <blob-id>      read config from given blob object
#
# Action
#     --get                 get value: name [value-regex]
#     --get-all             get all values: key [value-regex]
#     --get-regexp          get values for regexp: name-regex [value-regex]
#     --get-urlmatch        get value specific for the URL: section[.var] URL
#     --replace-all         replace all matching variables: name value [value_regex]
#     --add                 add a new variable: name value
#     --unset               remove a variable: name [value-regex]
#     --unset-all           remove all matches: name [value-regex]
#     --rename-section      rename section: old-name new-name
# ...
